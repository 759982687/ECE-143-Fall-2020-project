# %%
import numpy as np
import pandas as pd
import re
import emojis
import json
import matplotlib as mpl
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
file = open('save.json','r')
save = json.load(file)
df = pd.read_csv('Tweet.csv')

# %%
x = range(1,1579)
y = list(df['count'])
#len(y)

# %%
plt.figure(figsize=(30,10)) 
plt.tick_params(labelsize=40)
#plt.axes(yscale = "log",basey=2)
plt.yscale('log',basey=2)
plt.bar(x, y ,width =1,color = 'lightsteelblue') 
plt.title('G') 
plt.xlabel('Frequency Rank',size = 40)
plt.ylabel('Frequency',size = 40) 
#plt.show()
plt.savefig('all_emoji.png')

# %%
print(df)
# Out:
#      Unnamed: 0 emoji    count  polarity  subjectivity  position
# 0             0     😂  5137514  0.126684      0.330084  0.813158
# 1             1     😭  2024950  0.131789      0.359675  0.819218
# 2             2     🔥  1534100  0.231638      0.300448  0.685408
# 3             3     😍  1421397  0.372784      0.394112  0.768612
# 4             4    ❤️  1233906  0.394583      0.390217  0.761115
# ..          ...   ...      ...       ...           ...       ...
# 195         195     🔞    30447  0.202997      0.387735  0.598397
# 196         196     🐱    30345  0.367214      0.339761  0.703233
# 197         197     🍾    30126  0.421780      0.394166  0.736938
# 198         198     📍    30024  0.159193      0.207388  0.516921
# 199         199     🍆    29908  0.156729      0.319163  0.735148
#
# [200 rows x 6 columns]

# %%
df = pd.read_csv('good.csv')

# %%
min(df['polarity'])
# Out:
# -0.06531284216589801

# %%
import matplotlib.cm as cm
from matplotlib.colors import Normalize
qiao = []
for i in df['polarity']:
    qiao.append(i)
plt.figure(figsize=(40,15)) 
plt.tick_params(labelsize=40)
#fig, ax = plt.subplots(1, 1)
#my_cmap = cm.get_cmap('seismic')
my_cmap = cm.get_cmap('jet')
my_norm = Normalize(vmin=-0.3, vmax=0.6)
data = qiao
plt.yscale('log',basey=2)
plt.grid(axis = 'y')
plt.bar( df['Unnamed: 0'], df['count'] ,width =1,color=my_cmap(my_norm(data)))
#plt.title('G') 
plt.xlabel('200 Most Common Emoji',size = 40)
plt.ylabel('Frequency',size = 40) 
plt.savefig('200emoji1.png')

# %%
num = 40
import matplotlib.cm as cm
from matplotlib.colors import Normalize
qiao = []
for i in df['polarity']:
    qiao.append(i)
plt.figure(figsize=(40,15)) 
plt.tick_params(labelsize=40)
#fig, ax = plt.subplots(1, 1)
#my_cmap = cm.get_cmap('seismic')
my_cmap = cm.get_cmap('jet')
my_norm = Normalize(vmin=-0.3, vmax=0.6)
data = qiao
plt.yscale('log',basey=2)
plt.grid(axis = 'y')
plt.bar( df['Unnamed: 0'][:num], df['count'][:num] ,width =1,color=my_cmap(my_norm(data[:num])))
#plt.title('G') 
plt.xlabel('40 Most Common Emoji',size = 40)
plt.ylabel('Frequency',size = 40) 
plt.savefig('40emoji.png')

# %%
plt.figure(figsize=(10,5)) 
a =[]
b = []
for i in df['emoji'][:num]:
    a.append(i)
    b.append(emojis.decode(i))
word = str(a)
print(word)
print(b)
#type(word)
#word = 'qqqqqqqqqqq'
#plt.text(0.1,0.1,word,fontsize=120)
#plt.show()
# Out:
# ['😂', '😭', '🔥', '😍', '❤️', '💕', '👏', '🤣', '🙏', '✨', '😩', '😊', '👉', '💖', '🚨', '♀️', '😘', '🙌', '💜', '💯', '💀', '🎉', '💙', '🤔', '👀', '👍', '💗', '♂️', '🤷', '✅', '😁', '🤦', '💪', '💞', '🙄', '💥', '👌', '👇', '💓', '💛']
# [':joy:', ':sob:', ':fire:', ':heart_eyes:', ':heart:', ':two_hearts:', ':clap:', ':rofl:', ':pray:', ':sparkles:', ':weary:', ':blush:', ':point_right:', ':sparkling_heart:', ':rotating_light:', ':female_sign:', ':kissing_heart:', ':raised_hands:', ':purple_heart:', ':100:', ':skull:', ':tada:', ':blue_heart:', ':thinking:', ':eyes:', ':thumbsup:', ':heartpulse:', ':male_sign:', ':shrug:', ':white_check_mark:', ':grin:', ':facepalm:', ':muscle:', ':revolving_hearts:', ':roll_eyes:', ':collision:', ':ok_hand:', ':point_down:', ':heartbeat:', ':yellow_heart:']

# %%
qiao = []
for i in df['polarity']:
    qiao.append(i)
plt.figure(figsize=(40,15)) 


plt.tick_params(labelsize=40)
plt.hist( qiao,bins=20)
plt.xlabel('Sentiment Score',size = 40)
plt.ylabel('Different Emojis',size = 40) 
plt.savefig('200emoji_hist.png')

# %%
import matplotlib.cm as cm
from matplotlib.colors import Normalize
qiao = []
for i in df['subjectivity']:
    qiao.append(i)
plt.figure(figsize=(40,15)) 
plt.tick_params(labelsize=40)
#fig, ax = plt.subplots(1, 1)
#my_cmap = cm.get_cmap('seismic')
my_cmap = cm.get_cmap('jet')
my_norm = Normalize(vmin=0, vmax=0.8)
data = qiao
plt.yscale('log',basey=2)
plt.grid(axis = 'y')
plt.bar( df['Unnamed: 0'], df['count'] ,width =1,color=my_cmap(my_norm(data)))
#plt.title('G') 
plt.xlabel('200 Most Common Emoji',size = 40)
plt.ylabel('Frequency',size = 40) 
plt.savefig('200emoji_sub.png')

# %%
num = 40
import matplotlib.cm as cm
from matplotlib.colors import Normalize
qiao = []
for i in df['subjectivity']:
    qiao.append(i)
plt.figure(figsize=(40,15)) 
plt.tick_params(labelsize=40)
#fig, ax = plt.subplots(1, 1)
#my_cmap = cm.get_cmap('seismic')
my_cmap = cm.get_cmap('jet')
my_norm = Normalize(vmin=0, vmax=0.8)
data = qiao
plt.yscale('log',basey=2)
plt.grid(axis = 'y')
plt.bar( df['Unnamed: 0'][:num], df['count'][:num] ,width =1,color=my_cmap(my_norm(data[:num])))
#plt.title('G') 
plt.xlabel('40 Most Common Emoji',size = 40)
plt.ylabel('Frequency',size = 40) 
plt.savefig('40emoji_sub.png')

# %%
qiao = []
for i in df['subjectivity']:
    qiao.append(i)
plt.figure(figsize=(40,15)) 


plt.tick_params(labelsize=40)
plt.hist( qiao,bins=20)
plt.xlabel('Subjectivity Score',size = 40)
plt.ylabel('Different Emojis',size = 40) 
plt.savefig('200emoji_hist_sub.png')

# %%
import matplotlib.cm as cm
from matplotlib.colors import Normalize
import math
qiao = []
for i in df['polarity']:
    qiao.append(i)
qiao2 = []
for i in df['subjectivity']:
    qiao2.append(i)
qiao3 =[]
for i in df['count']:
    a  = int(math.log(i)/math.log(2))-13  
    qiao3.append((2**a)*10)
plt.figure(figsize=(20,20)) 
plt.tick_params(labelsize=20)
#fig, ax = plt.subplots(1, 1)
#my_cmap = cm.get_cmap('seismic')
my_cmap = cm.get_cmap('jet')
my_norm = Normalize(vmin=0, vmax=0.8)
data = qiao


plt.scatter( qiao, qiao2,s = qiao3 )#,color=my_cmap(my_norm(data)))
#plt.title('G') 
plt.xlabel('Sentiment Score',size = 40)
plt.ylabel('Subjectivity Score',size = 40) 
plt.savefig('two.png')

# %%
import math
qiao3 =[]
for i in df['count']:
    a  = int(math.log(i)/math.log(2))-13  
    qiao3.append(2**a)

# %%
import matplotlib.cm as cm
from matplotlib.colors import Normalize
import math
qiao = []
for i in df['polarity']:
    qiao.append(i)
qiao2 = []
for i in df['position']:
    qiao2.append(i)
qiao3 =[]
for i in df['count']:
    a  = int(math.log(i)/math.log(2))-13  
    qiao3.append((2**a)*10)
plt.figure(figsize=(20,20)) 
plt.tick_params(labelsize=20)
#fig, ax = plt.subplots(1, 1)
#my_cmap = cm.get_cmap('seismic')
my_cmap = cm.get_cmap('jet')
my_norm = Normalize(vmin=0, vmax=0.8)
data = qiao


plt.scatter( qiao, qiao2,s = qiao3 )#,color=my_cmap(my_norm(data)))
#plt.title('G') 
plt.xlabel('Sentiment Score',size = 40)
plt.ylabel('Position',size = 40) 
plt.savefig('position.png')

# %%
qiao = []
for i in df['position']:
    qiao.append(i)
plt.figure(figsize=(40,15)) 


plt.tick_params(labelsize=40)
plt.hist( qiao,bins=20)
plt.xlabel('Position',size = 40)
plt.ylabel('Different Emojis',size = 40) 
plt.savefig('200emoji_hist_position.png')

# %%
import json
file = open('data.json','r')
data = json.load(file)

# %%
file = open('save.json','r')
save = json.load(file)

# %%
emoji_list=[]
for i in save.keys():
    emoji_list.append(i)

# %%
emoji_list[1]
len(data[emoji_list[0]][3])
# Out:
# 847220

# %%
data[emoji_list[0]][1]
# Out:
# 1729908

# %%
a = data[emoji_list[0]]
def data_process(a):
    pol = []
    sub = []
    num = 0
    for i in range(len(a[2])):
        if a[2][i] != 0:
            pol.append(a[2][i])
            sub.append(a[3][i])
        elif num > 5:
            pol.append(a[2][i])
            sub.append(a[3][i])
            num=0
        else:
            num = num +1
    return pol,sub

pol,sub = data_process(a)

# %%
plt.figure(figsize=(40,15)) 
plt.tick_params(labelsize=40)
#plt.hist(pol ,bins=40)
plt.scatter( pol, sub)
#plt.xlabel('Position',size = 40)
#plt.ylabel('Different Emojis',size = 40) 
plt.savefig('first.png')

# %%
np.var(pol)
# Out:
# 0.14102850105429882

# %%
np.var(sub)
# Out:
# 0.09053270420107298

# %%
pol_var = []
sub_var = []
for i in range(len(emoji_list)):
    
    pol,sub = data_process(data[emoji_list[i]])
    pol_var.append(np.var(pol))
    sub_var.append(np.var(sub))

# %%
plt.plot(pol_var)
plt.show()

# %%
num = 200
import matplotlib.cm as cm
from matplotlib.colors import Normalize
qiao = []
for i in df['polarity']:
    qiao.append(i)
plt.figure(figsize=(40,15)) 
plt.tick_params(labelsize=40)
#fig, ax = plt.subplots(1, 1)
#my_cmap = cm.get_cmap('seismic')
my_cmap = cm.get_cmap('Greens')
my_norm = Normalize(vmin=0.05, vmax=0.2)
data = qiao
plt.yscale('log',basey=2)
plt.grid(axis = 'y')
plt.bar( df['Unnamed: 0'][:num], df['count'][:num] ,width =1,color=my_cmap(my_norm(pol_var[:num])))
#plt.title('G') 
plt.xlabel('200 Most Common Emoji',size = 40)
plt.ylabel('Frequency',size = 40) 
plt.savefig('200emoji_var.png')

# %%
num = 40
import matplotlib.cm as cm
from matplotlib.colors import Normalize
qiao = []
for i in df['polarity']:
    qiao.append(i)
plt.figure(figsize=(40,15)) 
plt.tick_params(labelsize=40)
#fig, ax = plt.subplots(1, 1)
#my_cmap = cm.get_cmap('seismic')
my_cmap = cm.get_cmap('Greens')
my_norm = Normalize(vmin=0.05, vmax=0.2)
data = qiao
plt.yscale('log',basey=2)
plt.grid(axis = 'y')
plt.bar( df['Unnamed: 0'][:num], df['count'][:num] ,width =1,color=my_cmap(my_norm(pol_var[:num])))
#plt.title('G') 
plt.xlabel('200 Most Common Emoji',size = 40)
plt.ylabel('Frequency',size = 40) 
plt.savefig('40emoji_var.png')

# %%
qiao = []
for i in df['subjectivity']:
    qiao.append(i)
#print(pol_var)
for i in range(5):
    for j in range(len(qiao)-3):
        if qiao[j] == min(qiao):
            print(j)
            del qiao[j]
# Out:
# 166
# 152
# 176
# 124
# 166
# 168
# 140
# 149
# 29

# %%
emoji_list[140]
# Out:
# '❌'

# %%
qiao = []
for i in df['subjectivity']:
    qiao.append(i)
qiao.remove(max(qiao))
max(qiao)
# Out:
# 0.5552854890837563

# %%
for j in range(len(qiao)):
    if qiao[j] == max(qiao):
        print(j)
qiao.remove(max(qiao))
for j in range(len(qiao)):
    if qiao[j] == max(qiao):
        print(j)
# Out:
# 21
# 146

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import sys
import os
import emoji

# %%
# Reader vs Writer
temp3 = pd.read_csv(os.path.join(sys.path[0], '__readervswriter.csv'))
# Emoji Table
temp4 = pd.read_csv(os.path.join(sys.path[0], 'ijstable.csv'))
# Employee questionaire votes
#temp5 = pd.read_csv(os.path.join(sys.path[0], 'votes_cleaned.csv'))

# Matplotlib formatting to allow the emojis to be displayed on the plot
prop = FontProperties(fname = 'C:\\Users\Administrator\Desktop\data\seguiemj.ttf')
#prop = FontProperties(fname = 'C:\\Windows\\Fonts\\seguiemj.ttf')
# Substitute Emoji List of incorrect names with correct names
emoji_list = []
error_list =[':dancing_woman:',':person_raising_both_hands_in_celebration:', ':clapping_hands_sign:',':christmas_tree:',':multiple_musical_notes:',':thumbs_up_sign:',
            ':face_throwing_a_kiss:', ':face_with_stuck-out_tongue_and_winking_eye:',':ok_hand_sign:',':wrapped_present:',':person_with_folded_hands:',':thumbs_down_sign:',
            ':disappointed_but_relieved_face:',':face_with_cold_sweat:']

sub_list = [':woman_dancing:',':raising_hands:',':clapping_hands:',':Christmas_tree:',':musical_notes:',':thumbs_up:',':face_blowing_a_kiss:', ':winking_face_with_tongue:',
            ':OK_hand:',':wrapped_gift:',':folded_hands:',':thumbs_down:',':sad_but_relieved_face:',':downcast_face_with_sweat:']

for i in range(len(temp3['description'])):
    if ':'+str(temp3['description'][i]).lower().replace(' ','_')+':' not in error_list:
        emoji_list.append(emoji.emojize(':'+str(temp3['description'][i]).lower().replace(' ','_')+':'))
        # emoji_list.append(emojis.encode(':'+str(temp3['description'][i]).lower().replace(' ','_')+':'))
    else:
        ind = error_list.index(':'+str(temp3['description'][i]).lower().replace(' ','_')+':')
        emoji_list.append(emoji.emojize(sub_list[ind]))
        # emoji_list.append(emojis.encode(sub_list[ind]))

# Sort list
sort_list = sorted(zip(temp3['diff'], temp3['description']))
# print(sort_list)

# Plots Emoji Count
# p1 = plt.bar(range(len(temp3['s.writer'])),temp3['count'])
# for rect1, label in zip(p1, emoji_list):
#     height = rect1.get_height()
#     plt.annotate(
#         label,
#         (rect1.get_x() + rect1.get_width()/2, height),
#         ha="center",
#         va="bottom",
#         fontsize=15,
#         fontproperties=prop
#     )
# plt.title("Emoji Count")
# plt.ylabel("Frequency")
# plt.show()

### Plots Writer Sentiment and Reader Sentiment ###
width = 0.35
fig, ax = plt.subplots()
x = np.arange(len(temp3['s.writer']))
rects1 = ax.bar(x - width/2, temp3['s.writer'], width, label='Writer Sentiment')
rects2 = ax.bar(x + width/2, temp3['s.reader'], width, label='Reader Sentiment')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Happiness Level')
ax.set_title('Happiness Level Based on Emojis Used')
ax.set_xticks(x)
ax.set_xticklabels(x)
ax.legend()


def autolabel(rects):
    """Attach a text label above each bar in rects, displaying its height."""
    for rect , label in zip(rects, emoji_list):
        height = rect.get_height()
        if height < 0:
            height = height - 0.05
        ax.annotate(label,
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom',
                    fontproperties = prop)


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()
plt.show()

### Plots sentiment difference between writer and reader for each emoji ### 
p1 = plt.bar(x,temp3['diff'])
plt.title("Difference Between Write and Reader Sentiment")
plt.ylabel("Difference")
for rect1, label in zip(p1, emoji_list):
    height = rect1.get_height()
    if height < 0:
        height = height - 0.03
    plt.annotate(
        label,
        (rect1.get_x() + rect1.get_width()/2, height),
        ha="center",
        va="bottom",
        fontsize=15,
        fontproperties=prop
    )
plt.show()

### Plots the standard deviation for each emoji ###
p1 = plt.bar(x,temp3['sd'])
plt.title("Standard Deviation Between Write and Reader Sentiment")
plt.ylabel("SD")
for rect1, label in zip(p1, emoji_list):
    height = rect1.get_height()
    if height < 0:
        height = height - 0.05
    plt.annotate(
        label,
        (rect1.get_x() + rect1.get_width()/2, height),
        ha="center",
        va="bottom",
        fontsize=15,
        fontproperties=prop
    )
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55357 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 56473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 56858 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 55356 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 57211 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
